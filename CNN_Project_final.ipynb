# %% [markdown]
# ## 이미지 준비
#
# 현재 컴퓨터에 이미지 파일이 존재할 경우 아래 코드를 수행하지 않고 기본 변수 중 path 변경

# %%
# 이미 다운받은 데이터셋 삭제 (다운받은 데이터셋이 없어도 동작함)
# !rm -rf Cifar10.tar.gz
# !rm -rf Cifar10/

# 데이터셋 다운로드
# !wget -q https://raw.githubusercontent.com/panggin/AI2021_project/main/Cifar10.tar.gz
# !tar -xzf Cifar10.tar.gz

# !ls
# Out:
# Cifar10  Cifar10.tar.gz  sample_data

# %% [markdown]
# ## 필요한 라이브러리 호출

# %%
# 라이브러리 호출
import matplotlib.pyplot as plt
import numpy as np

import glob
from skimage.io import imread   # 이미지 불러오기
from skimage.transform import resize   # 이미지 크기 조정
from sklearn.utils import shuffle

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras import layers, models
from keras.layers import Dense, Dropout, BatchNormalization

import os
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ## 기본 변수 및 함수 정의

# %%
# 상수 사용을 위함
class Default:
    imgR     = 32
    imgC     = 32
    channel  = 3
    imgCount = 6000
    split    = 5000

# %%
# Label,Data Path Definition
class_labels = { 0:'airplane', 1:'automobile',2:'bird', 3:'cat', 4:'deer', 
                5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}

path = './Cifar10/' # 분류별 이미지 폴더가 저장된 위치

# %%
# Visualize Image
def plot_images(nRow,nCol,img):
    fig = plt.figure()
    fig,ax = plt.subplots(nRow,nCol,figsize=(nCol,nRow))
    for i in range(nRow):
        for j in range(nCol):
            if nRow <= 1: axis = ax[j]
            else:         axis = ax[i,j]
            axis.get_xaxis().set_visible(False)
            axis.get_yaxis().set_visible(False)
            axis.imshow(img[i*nCol+j])

##### Dataset load #####
# get image path from each class
def get_image_path_dict(main_path, class_labels):
    paths_dict = {} # 분류별 이미지 경로를 딕셔너리로 저장
    for label in class_labels:
        paths = glob.glob(main_path + class_labels[label] + '/*.jpg')
        paths_dict[label] = np.array(paths)
    print('Done: get image path dictionary') # for debugging
    return paths_dict

# set x, y data of each class
def set_xy_dict(paths_dict, class_labels):
    x_dict, y_dict = {}, {}
    for label in class_labels:
        x_dict[label] = np.array([imread(paths_dict[label][i])
                                    for i in range(Default.imgCount)])
        x_dict[label] = np.array([resize(x_dict[label][i], 
                                        (Default.imgR, Default.imgC, Default.channel)) 
                                    for i in range(Default.imgCount)])
        y_dict[label] = np.full(Default.imgCount, label)
        print(f'{label}: {x_dict[label].shape} {y_dict[label].shape}')
    print('Done: set x, y dictionary') # for debugging
    return x_dict, y_dict

# split train/test data
def split_dict(x_dict, y_dict, class_labels):
    x_dict_train, x_dict_test = {}, {}
    y_dict_train, y_dict_test = {}, {}
    for label in class_labels:
        x_dict_train[label] = x_dict[label][:Default.split]
        x_dict_test[label]  = x_dict[label][Default.split:]
        y_dict_train[label] = y_dict[label][:Default.split]
        y_dict_test[label]  = y_dict[label][Default.split:]
        print(f'train {label}: {x_dict_train[label].shape} {y_dict_train[label].shape}')
        print(f'test {label}: {x_dict_test[label].shape} {y_dict_test[label].shape}')
    print('Done: split x,y dict --> train/test') # for debugging
    return x_dict_train, x_dict_test, y_dict_train, y_dict_test 

# set x, y data - concatenate
def set_xy(x_dict_train, x_dict_test, 
           y_dict_train, y_dict_test, class_labels):
    x_train = np.concatenate([x_dict_train[label] for label in class_labels])
    x_test  = np.concatenate([x_dict_test[label]  for label in class_labels])
    y_train = np.concatenate([y_dict_train[label] for label in class_labels])
    y_test =  np.concatenate([y_dict_test[label]  for label in class_labels])

    # shuffle x, y
    x_train, y_train = shuffle(x_train, y_train)
    x_test,  y_test  = shuffle(x_test, y_test)
    print('Done: set x, y data') # for debugging
    return (x_train, y_train), (x_test, y_test)

# data load
def data_load(path, class_labels):
    paths_dict = get_image_path_dict(path, class_labels)
    x_dict, y_dict = set_xy_dict(paths_dict, class_labels)
    (x_dict_train, x_dict_test, 
     y_dict_train, y_dict_test) = split_dict(x_dict, y_dict, class_labels)
    (x_train, y_train), (x_test, y_test) = set_xy(x_dict_train, x_dict_test,
                                                  y_dict_train, y_dict_test,
                                                  class_labels)
    print('Successfully load data') # for debugging
    return (x_train, y_train), (x_test, y_test)

# %% [markdown]
# ## 데이터셋 로드

# %%
# 데이터셋 로드
(train_images, train_labels), (test_images, test_labels) = data_load(path, class_labels)

print(f'train data: {train_images.shape} {train_labels.shape}')
print(f'test data: {test_images.shape} {test_labels.shape}')
# Out:
# Done: get image path dictionary
# 0: (6000, 32, 32, 3) (6000,)
# 1: (6000, 32, 32, 3) (6000,)
# 2: (6000, 32, 32, 3) (6000,)
# 3: (6000, 32, 32, 3) (6000,)
# 4: (6000, 32, 32, 3) (6000,)
# 5: (6000, 32, 32, 3) (6000,)
# 6: (6000, 32, 32, 3) (6000,)
# 7: (6000, 32, 32, 3) (6000,)
# 8: (6000, 32, 32, 3) (6000,)
# 9: (6000, 32, 32, 3) (6000,)
# Done: set x, y dictionary
# train 0: (5000, 32, 32, 3) (5000,)
# test 0: (1000, 32, 32, 3) (1000,)
# train 1: (5000, 32, 32, 3) (5000,)
# test 1: (1000, 32, 32, 3) (1000,)
# train 2: (5000, 32, 32, 3) (5000,)
# test 2: (1000, 32, 32, 3) (1000,)
# train 3: (5000, 32, 32, 3) (5000,)
# test 3: (1000, 32, 32, 3) (1000,)
# train 4: (5000, 32, 32, 3) (5000,)
# test 4: (1000, 32, 32, 3) (1000,)
# train 5: (5000, 32, 32, 3) (5000,)
# test 5: (1000, 32, 32, 3) (1000,)
# train 6: (5000, 32, 32, 3) (5000,)
# test 6: (1000, 32, 32, 3) (1000,)
# train 7: (5000, 32, 32, 3) (5000,)
# test 7: (1000, 32, 32, 3) (1000,)
# train 8: (5000, 32, 32, 3) (5000,)
# test 8: (1000, 32, 32, 3) (1000,)
# train 9: (5000, 32, 32, 3) (5000,)
# test 9: (1000, 32, 32, 3) (1000,)
# Done: split x,y dict --> train/test
# Done: set x, y data
# Successfully load data
# train data: (50000, 32, 32, 3) (50000,)
# test data: (10000, 32, 32, 3) (10000,)

# %%
plot_images(2,5,train_images[:10])
print(train_labels[:10])
plot_images(2,5,test_images[:10])
print(test_labels[:10])
# Out:
# [1 4 3 1 8 4 4 0 5 2]
# [5 9 8 3 9 6 4 0 3 8]

# %% [markdown]
# ## CNN 모델 생성 및 학습

# %%
# CNN 인공신경망 정의
def create_model():
    model = Sequential()

    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu', input_shape=(32,32,3)))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(32, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.4))
    model.add(layers.Conv2D(128, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.4))

    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))
    model.add(layers.Conv2D(64, (3,3), padding='same', activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.Dropout(0.3))

    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.3))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer='adam', 
                  loss='sparse_categorical_crossentropy', 
                  metrics=['accuracy'])
    
    return model

# %%
# !rm -rf Training_checkpoint/ # 가중치 저장 파일 전체 삭제

# %%
# 가중치 정보 저장 경로
checkpoint_dir = 'Training_checkpoint/'
checkpoint_path = checkpoint_dir + 'cp-{epoch:04d}-{val_loss:.2f}.ckpt'

# 5번 에포크씩 val_loss 변화 확인- 변화 없을 시 학습 중단
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
cp = ModelCheckpoint(filepath=checkpoint_path, verbose=1,
                     save_weights_only=True,
                     save_best_only=True)

# %%
model = create_model()
# Checking the model summary
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_72 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_81 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  conv2d_73 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_82 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_36 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_63 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_74 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_83 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_75 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_84 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_37 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_64 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_76 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_85 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  dropout_65 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_77 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_86 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_38 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_66 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_78 (Conv2D)          (None, 4, 4, 64)          73792
#
#  batch_normalization_87 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  dropout_67 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_79 (Conv2D)          (None, 4, 4, 64)          36928
#
#  batch_normalization_88 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  max_pooling2d_39 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  dropout_68 (Dropout)        (None, 2, 2, 64)          0
#
#  flatten_9 (Flatten)         (None, 256)               0
#
#  dense_18 (Dense)            (None, 128)               32896
#
#  batch_normalization_89 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_69 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 434,730
# Trainable params: 433,322
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=500,
                    callbacks=[early_stopping, cp],
                    validation_split = 0.2, verbose=0)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
#
# Epoch 00001: val_loss improved from inf to 3.19226, saving model to Training_checkpoint/cp-0001-3.19.ckpt
#
# Epoch 00002: val_loss improved from 3.19226 to 1.44579, saving model to Training_checkpoint/cp-0002-1.45.ckpt
#
# Epoch 00003: val_loss improved from 1.44579 to 1.15447, saving model to Training_checkpoint/cp-0003-1.15.ckpt
#
# Epoch 00004: val_loss improved from 1.15447 to 1.08523, saving model to Training_checkpoint/cp-0004-1.09.ckpt
#
# Epoch 00005: val_loss improved from 1.08523 to 0.98009, saving model to Training_checkpoint/cp-0005-0.98.ckpt
#
# Epoch 00006: val_loss improved from 0.98009 to 0.85162, saving model to Training_checkpoint/cp-0006-0.85.ckpt
#
# Epoch 00007: val_loss improved from 0.85162 to 0.83804, saving model to Training_checkpoint/cp-0007-0.84.ckpt
#
# Epoch 00008: val_loss did not improve from 0.83804
#
# Epoch 00009: val_loss improved from 0.83804 to 0.83154, saving model to Training_checkpoint/cp-0009-0.83.ckpt
#
# Epoch 00010: val_loss improved from 0.83154 to 0.71197, saving model to Training_checkpoint/cp-0010-0.71.ckpt
#
# Epoch 00011: val_loss did not improve from 0.71197
#
# Epoch 00012: val_loss improved from 0.71197 to 0.70990, saving model to Training_checkpoint/cp-0012-0.71.ckpt
#
# Epoch 00013: val_loss did not improve from 0.70990
#
# Epoch 00014: val_loss improved from 0.70990 to 0.68282, saving model to Training_checkpoint/cp-0014-0.68.ckpt
#
# Epoch 00015: val_loss improved from 0.68282 to 0.63498, saving model to Training_checkpoint/cp-0015-0.63.ckpt
#
# Epoch 00016: val_loss did not improve from 0.63498
#
# Epoch 00017: val_loss improved from 0.63498 to 0.62216, saving model to Training_checkpoint/cp-0017-0.62.ckpt
#
# Epoch 00018: val_loss did not improve from 0.62216
#
# Epoch 00019: val_loss did not improve from 0.62216
#
# Epoch 00020: val_loss did not improve from 0.62216
#
# Epoch 00021: val_loss improved from 0.62216 to 0.59034, saving model to Training_checkpoint/cp-0021-0.59.ckpt
#
# Epoch 00022: val_loss did not improve from 0.59034
#
# Epoch 00023: val_loss improved from 0.59034 to 0.58568, saving model to Training_checkpoint/cp-0023-0.59.ckpt
#
# Epoch 00024: val_loss did not improve from 0.58568
#
# Epoch 00025: val_loss improved from 0.58568 to 0.57948, saving model to Training_checkpoint/cp-0025-0.58.ckpt
#
# Epoch 00026: val_loss did not improve from 0.57948
#
# Epoch 00027: val_loss improved from 0.57948 to 0.57823, saving model to Training_checkpoint/cp-0027-0.58.ckpt
#
# Epoch 00028: val_loss did not improve from 0.57823
#
# Epoch 00029: val_loss did not improve from 0.57823
#
# Epoch 00030: val_loss did not improve from 0.57823
#
# Epoch 00031: val_loss improved from 0.57823 to 0.56728, saving model to Training_checkpoint/cp-0031-0.57.ckpt
#
# Epoch 00032: val_loss improved from 0.56728 to 0.54766, saving model to Training_checkpoint/cp-0032-0.55.ckpt
#
# Epoch 00033: val_loss did not improve from 0.54766
#
# Epoch 00034: val_loss did not improve from 0.54766
#
# Epoch 00035: val_loss did not improve from 0.54766
#
# Epoch 00036: val_loss did not improve from 0.54766
#
# Epoch 00037: val_loss improved from 0.54766 to 0.54715, saving model to Training_checkpoint/cp-0037-0.55.ckpt
#
# Epoch 00038: val_loss improved from 0.54715 to 0.53633, saving model to Training_checkpoint/cp-0038-0.54.ckpt
#
# Epoch 00039: val_loss did not improve from 0.53633
#
# Epoch 00040: val_loss improved from 0.53633 to 0.53286, saving model to Training_checkpoint/cp-0040-0.53.ckpt
#
# Epoch 00041: val_loss did not improve from 0.53286
#
# Epoch 00042: val_loss improved from 0.53286 to 0.53177, saving model to Training_checkpoint/cp-0042-0.53.ckpt
#
# Epoch 00043: val_loss did not improve from 0.53177
#
# Epoch 00044: val_loss did not improve from 0.53177
#
# Epoch 00045: val_loss did not improve from 0.53177
#
# Epoch 00046: val_loss did not improve from 0.53177
#
# Epoch 00047: val_loss did not improve from 0.53177
#
# Epoch 00048: val_loss did not improve from 0.53177
#
# Epoch 00049: val_loss did not improve from 0.53177
#
# Epoch 00050: val_loss improved from 0.53177 to 0.52930, saving model to Training_checkpoint/cp-0050-0.53.ckpt
#
# Epoch 00051: val_loss did not improve from 0.52930
#
# Epoch 00052: val_loss did not improve from 0.52930
#
# Epoch 00053: val_loss did not improve from 0.52930
#
# Epoch 00054: val_loss improved from 0.52930 to 0.51365, saving model to Training_checkpoint/cp-0054-0.51.ckpt
#
# Epoch 00055: val_loss improved from 0.51365 to 0.51197, saving model to Training_checkpoint/cp-0055-0.51.ckpt
#
# Epoch 00056: val_loss improved from 0.51197 to 0.50687, saving model to Training_checkpoint/cp-0056-0.51.ckpt
#
# Epoch 00057: val_loss did not improve from 0.50687
#
# Epoch 00058: val_loss did not improve from 0.50687
#
# Epoch 00059: val_loss did not improve from 0.50687
#
# Epoch 00060: val_loss did not improve from 0.50687
#
# Epoch 00061: val_loss did not improve from 0.50687
#
# Epoch 00062: val_loss did not improve from 0.50687
#
# Epoch 00063: val_loss did not improve from 0.50687
#
# Epoch 00064: val_loss improved from 0.50687 to 0.50429, saving model to Training_checkpoint/cp-0064-0.50.ckpt
#
# Epoch 00065: val_loss did not improve from 0.50429
#
# Epoch 00066: val_loss did not improve from 0.50429
#
# Epoch 00067: val_loss did not improve from 0.50429
#
# Epoch 00068: val_loss did not improve from 0.50429
#
# Epoch 00069: val_loss did not improve from 0.50429
#
# Epoch 00070: val_loss did not improve from 0.50429
#
# Epoch 00071: val_loss did not improve from 0.50429
#
# Epoch 00072: val_loss did not improve from 0.50429
#
# Epoch 00073: val_loss did not improve from 0.50429
#
# Epoch 00074: val_loss improved from 0.50429 to 0.49485, saving model to Training_checkpoint/cp-0074-0.49.ckpt
#
# Epoch 00075: val_loss did not improve from 0.49485
#
# Epoch 00076: val_loss did not improve from 0.49485
#
# Epoch 00077: val_loss did not improve from 0.49485
#
# Epoch 00078: val_loss did not improve from 0.49485
#
# Epoch 00079: val_loss did not improve from 0.49485
#
# Epoch 00080: val_loss did not improve from 0.49485
#
# Epoch 00081: val_loss did not improve from 0.49485
#
# Epoch 00082: val_loss did not improve from 0.49485
#
# Epoch 00083: val_loss did not improve from 0.49485
#
# Epoch 00084: val_loss did not improve from 0.49485

# %% [markdown]
# ## 학습 결과 확인

# %%
# Loss curve
plt.figure(figsize=[6,4])
plt.plot(history.history['loss'], 'black', linewidth=2.0)
plt.plot(history.history['val_loss'], 'green', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Loss Curves')

# %%
# Accuracy curve
plt.figure(figsize=[6,4])
plt.plot(history.history['accuracy'], 'black', linewidth=2.0)
plt.plot(history.history['val_accuracy'], 'blue', linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy', fontsize=10)
plt.title('Accuracy Curves', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %% [markdown]
# ## 학습한 모델 및 history 정보 파일로 저장

# %%
# !rm -rf cifar10/

# %%
# 모델 저장
model.save('cifar10/savedModel/')
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# INFO:tensorflow:Assets written to: cifar10/savedModel/assets

# %%
# history 파일로 저장
history_df = pd.DataFrame(history.history)

with open('cifar10/history.csv', mode='w') as hist_file:
    history_df.to_csv(hist_file)

# %%
##### checkpoint로부터 모델 복원
latest = tf.train.latest_checkpoint(checkpoint_dir)
model = create_model()
model.load_weights(latest)
loss, acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 3s - loss: 0.3076 - accuracy: 0.8951 - 3s/epoch - 10ms/step

# %%
##### savedModel에 저장된 모델 복원
model = keras.models.load_model('cifar10/savedModel/')
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_80 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_90 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  conv2d_81 (Conv2D)          (None, 32, 32, 32)        9248
#
#  batch_normalization_91 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  max_pooling2d_40 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  dropout_70 (Dropout)        (None, 16, 16, 32)        0
#
#  conv2d_82 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_92 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  conv2d_83 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_93 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  max_pooling2d_41 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  dropout_71 (Dropout)        (None, 8, 8, 64)          0
#
#  conv2d_84 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_94 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  dropout_72 (Dropout)        (None, 8, 8, 128)         0
#
#  conv2d_85 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_95 (Bat  (None, 8, 8, 128)        512
#  chNormalization)
#
#  max_pooling2d_42 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  dropout_73 (Dropout)        (None, 4, 4, 128)         0
#
#  conv2d_86 (Conv2D)          (None, 4, 4, 64)          73792
#
#  batch_normalization_96 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  dropout_74 (Dropout)        (None, 4, 4, 64)          0
#
#  conv2d_87 (Conv2D)          (None, 4, 4, 64)          36928
#
#  batch_normalization_97 (Bat  (None, 4, 4, 64)         256
#  chNormalization)
#
#  max_pooling2d_43 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  dropout_75 (Dropout)        (None, 2, 2, 64)          0
#
#  flatten_10 (Flatten)        (None, 256)               0
#
#  dense_20 (Dense)            (None, 128)               32896
#
#  batch_normalization_98 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_76 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 434,730
# Trainable params: 433,322
# Non-trainable params: 1,408
# _________________________________________________________________

# %%
##### history 파일 로드 --> 그래프 확인
history_df = pd.read_csv('cifar10/history.csv')

# Loss curve
plt.figure(figsize=[6,4])
plt.plot(history_df['loss'], 'black', linewidth=2.0)
plt.plot(history_df['val_loss'], 'green', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves', fontsize=12)
plt.show()
plt.close()

# Accuracy curve
plt.figure(figsize=[6,4])
plt.plot(history_df['accuracy'], 'black', linewidth=2.0)
plt.plot(history_df['val_accuracy'], 'blue', linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy', fontsize=10)
plt.title('Accuracy Curves', fontsize=12)
plt.show()
plt.close()

# %% [markdown]
# ## 모델 예측 성능 확인

# %%
np.argmax(model.predict(test_images[0:100]), axis=1)
# Out:
# array([8, 4, 1, 7, 7, 4, 3, 7, 8, 5, 3, 0, 5, 0, 2, 6, 3, 7, 0, 7, 4, 2,
#        9, 3, 0, 5, 6, 8, 1, 1, 0, 6, 0, 5, 3, 0, 7, 4, 9, 8, 6, 5, 1, 5,
#        3, 3, 1, 5, 4, 2, 9, 5, 5, 9, 3, 1, 5, 4, 1, 0, 6, 8, 7, 2, 4, 3,
#        5, 7, 0, 3, 1, 6, 6, 7, 4, 1, 2, 0, 0, 1, 3, 4, 7, 7, 9, 5, 6, 4,
#        5, 8, 7, 7, 6, 5, 0, 4, 8, 2, 8, 1])

# %%
pred = model.predict(test_images)
print(pred)
print(pred.shape)

# Converting the predictions into label index 
pred_labels = np.argmax(pred, axis=1)
print(pred_labels)
# Out:
# [[2.1045676e-03 4.5482724e-05 1.6276786e-05 ... 4.1036587e-06
#   9.9763346e-01 7.8306031e-05]
#  [5.2499894e-05 4.2534020e-06 3.3035036e-03 ... 3.6685138e-05
#   2.7755354e-05 2.3903529e-05]
#  [1.5523079e-04 9.5725811e-01 7.1036629e-05 ... 3.0213048e-06
#   8.4823892e-05 4.1994300e-02]
#  ...
#  [3.3396217e-03 2.0870792e-02 3.6284287e-02 ... 5.3544459e-04
#   2.8800088e-04 2.6491717e-02]
#  [1.0252474e-01 1.3613085e-03 3.7549583e-03 ... 2.6852536e-01
#   4.3701082e-01 1.7572387e-01]
#  [1.3381042e-01 1.4713289e-05 7.6465791e-01 ... 4.0988424e-03
#   8.1644906e-04 7.1151368e-04]]
# (10000, 10)
# [8 4 1 ... 6 8 2]

# %%
# Plotting the Actual vs. Predicted results

fig, axes = plt.subplots(10, 10, figsize=(20,20))
axes = axes.ravel()

random_idx = np.random.randint(10000, size=100)

for i,idx in enumerate(random_idx):
    axes[i].imshow(test_images[idx])
    true_label, pred_label = class_labels[test_labels[idx]], class_labels[pred_labels[idx]]
    if true_label != pred_label: axes[i].set_title("True: %s \nPredict: %s" % (true_label, pred_label), color='red')
    else : axes[i].set_title("True: %s \nPredict: %s" % (true_label, pred_label))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('테스트 정확도:',test_acc)
# Out:
# 313/313 - 3s - loss: 0.3076 - accuracy: 0.8951 - 3s/epoch - 8ms/step
# 테스트 정확도: 0.8950999975204468

# %%
# 가중치 저장 폴더 압축
# !zip Training_checkpoint.zip -r Training_checkpoint/
# 모델 저장된 폴더 압축
# !zip Team2_model.zip -r cifar10/

# %%
# !tar zcvf Team2_model.tar.gz cifar10/
# Out:
# cifar10/
# cifar10/savedModel/
# cifar10/savedModel/assets/
# cifar10/savedModel/variables/
# cifar10/savedModel/variables/variables.data-00000-of-00001
# cifar10/savedModel/variables/variables.index
# cifar10/savedModel/keras_metadata.pb
# cifar10/savedModel/saved_model.pb
# cifar10/history.csv
